# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from galpy.potential import NFWPotential, HernquistPotential
from galpy.potential import plotRotcurve
from galpy.orbit import Orbit

# %%
np= NFWPotential(a=3.5,normalize=.35)
o1 = Orbit(vxvv=[1.,0.1,1.1,0.,0.3,0.0]) #[R,vR,vT(,z,vz,phi)]
o2 = Orbit(vxvv=[1.1,0.1,1.1,0.,0.3,0.0])

ts = linspace(0,100,10000)

o1.integrate(ts,np,method='odeint')
o2.integrate(ts,np,method='odeint')

# %%
o1.plot(d1='t',d2='phi')

# %%
print o1.phi(100000)
# Out:
# 6.01854426977

# %%
data = o1.getOrbit()

# %%
phi = data[:,5]

# %%
plot(data[:,3])
